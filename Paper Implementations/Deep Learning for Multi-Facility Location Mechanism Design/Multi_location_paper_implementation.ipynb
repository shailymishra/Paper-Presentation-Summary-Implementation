# %% [markdown]
# <a href="https://colab.research.google.com/github/shailymishra/Paper-Presentation-Summary-Implementation/blob/main/Multi_location_paper_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Imports
import torch

import os
import numpy as np
import pandas as pd
import pandas.util.testing as tm
from tqdm import tqdm
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from torch import nn, optim

import torch.nn.functional as F
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import sys

# %%
n_agents = 5
n_samples = 3000
n_train_samples =1500
use_cuda = torch.cuda.is_available()

# %%
### Data Representation of Moulin net
### Example of a data samples
#### tensor([ 1.0000, -1.0000, -1.0000, -1.0000, -1.0000,  0.2848,  
####          1.0000, -1.0000, 1.0000, -1.0000, -1.0000,  0.3309,  
#####         1.0000, -1.0000,  1.0000, -1.0000,  1.0000,  0.6133,  
#####         1.0000,  1.0000,  1.0000, -1.0000,  1.0000,  0.6381, 
####          1.0000,  1.0000,  1.0000,  1.0000,  1.0000,  0.8180])

peaks = []
for i in range(n_agents):
  peak = np.random.rand(n_samples)
  peaks.append(peak)
peaks = np.array(peaks)

def getbinaryrepresentation(array):
  representation = np.full((n_agents), -1)
  for value in array:
    representation[value] = 1
  return representation

def generateDataSamples(peaks):
  samples = []
  for i in range(n_samples):
    datasample = []
    currentpeaks = peaks[:,i]
    currentorder = np.argsort(currentpeaks)
    sortedorder = currentpeaks[currentorder]
    for j in range(n_agents):
      representation = getbinaryrepresentation(currentorder[:j+1])
      datasample.extend(representation)
      datasample.append(sortedorder[j])
    samples.append(datasample)
  return torch.FloatTensor(samples)


moulin_net_data = generateDataSamples(peaks)

# %%
## Moulin net data - split in train and test
indices = np.random.permutation(moulin_net_data.shape[0])
training_idx, test_idx = indices[:n_train_samples], indices[n_train_samples:]
moulin_train_data, moulin_test_data = moulin_net_data[training_idx,:], moulin_net_data[test_idx,:]
print('moulin training shape', moulin_train_data.shape)
print('moulin testing shape', moulin_test_data.shape)
# Out:
# moulin training shape torch.Size([1500, 30])
# moulin testing shape torch.Size([1500, 30])

# %%
### Data Representation of Regret net
## Example of data sample for regret net
## tensor([0.1636, 0.6789, 0.8631, 0.2081, 0.8195])

peaks = np.array([])
for i in range(n_agents):
  peak = np.random.rand(n_samples)
  if(len(peaks) == 0):
    peaks = peak
  else:
    peaks =  np.dstack((peaks,peak))

peaks = np.reshape(peaks, (n_samples, n_agents ))
regret_net_data = torch.FloatTensor(peaks)

# %%
## Regret net data - split in train and test
indices = np.random.permutation(regret_net_data.shape[0])
training_idx, test_idx = indices[:n_train_samples], indices[n_train_samples:]
regretnet_train_data, regretnet_test_data = regret_net_data[training_idx,:], regret_net_data[test_idx,:]
print('regret training shape', regretnet_train_data.shape)
print('regret testing shape', regretnet_test_data.shape)
# Out:
# regret training shape torch.Size([1500, 5])
# regret testing shape torch.Size([1500, 5])

# %%
class MoulinNet(nn.Module):
    def __init__(self, n_agents, K):
        super(MoulinNet, self).__init__()
        self.n_agents = n_agents
        self.K = K
        self.L = 3
        self.J = 3
        self.datasamplelength = (n_agents+1)*n_agents
        ## if there are K facility, replicate the network K times
        self.asNN = nn.ModuleList([ nn.Linear(self.n_agents,self.L*self.J)   for i in range(K)])
        
    def forward(self, x):
        ## Outputvalues will contain the location of all K facilities for each data samples
        outputvalues = torch.tensor([])
        for k in range(self.K):
          X_clone = x.clone()

          ## Passing through a_s  neural network 
          ## from s get the a_s value
          ## looping for each s value i.e. where number of s values are equal to no of agents
          for i in range(0, self.datasamplelength  ,  self.n_agents+1  ):
            ## layer 1 :  Pass through NN 
            tempvalue = self.asNN[k](X_clone[:,i:i+self.n_agents].clone())
            ## layer 2 : get maximum 
            for j in range(0, self.L*self.J,self.J):
              maxvalue_as, indicies = tempvalue[:,j:j+self.J].max(axis=1)
              maxvalue_as = maxvalue_as.unsqueeze_(-1)
              tempvalue[:,j:j+self.J] = maxvalue_as.clone()   
            ## layer 3 : get minimum
            minvalue_as, indicies = tempvalue.min(axis=1)
            minvalue_as = minvalue_as.unsqueeze_(-1)

            ### replacing the X_clone value with the minvalue obtained for s
            ### Before : 
            X_clone[:,i:i+self.n_agents] = minvalue_as.clone()
            ### After : 

          ## overall X_clone[0] will look like 


          ## Take maximum of a_s and peak
          for i in range(0, (self.n_agents+1)*self.n_agents  ,  self.n_agents+1  ):
            maxvalue, indicies = X_clone[:,i:i+self.n_agents+1].max(axis=1)
            maxvalue = maxvalue.unsqueeze_(-1)
            X_clone[:,i:i+self.n_agents+1] = maxvalue.clone()

          ## from all that is left, take min and that is the location we obtain
          minvalue, indicies = X_clone.min(axis=1)
          minvalue = minvalue.unsqueeze_(-1)

          ## for each K, append it to outputvalues
          outputvalues  = torch.cat([outputvalues, minvalue.clone()], axis=1)
        return outputvalues

    def loss_function(self, y, x):
      loss = torch.tensor([])
      ## For each facility
      for k in range(self.K):
        ## fetch localtion for kth facility for all data points      
        location_of_k_facility = y[:,k:k+1]
        ## calculate loss i.e. peak - location
        ### for now we are using x as whole to substract, later we will make all entries 0 expect the peak ones
        appendloss = torch.add(x,-location_of_k_facility)    
        ### append to loss for each facility
        loss  = torch.cat([loss,appendloss ], axis = 1)

      loss = torch.abs(loss)
      loss = torch.reshape(loss, (x.shape[0],self.K,self.datasamplelength) )

      ## for each each agent, we choose the minimum loss , i.e. loss corresponding to the location closest to its peak
      loss , indices = torch.min(loss, axis=1)

      ## all the entries expected peaks => 0      
      for i in range(0,(self.n_agents+1)*self.n_agents, self.n_agents+1 ):
        loss[:,i : i+self.n_agents] = 0  
      
      ## loss will be mean over all data sample, and for each data sample , mean over n_agents
      loss = torch.mean((torch.sum(  loss , dim=1))/self.n_agents)
      return loss

# %%
## 26 May 20
## multi facility
class RegretNet(nn.Module):
    def __init__(self, n_agents,K):
        super(RegretNet, self).__init__()
        self.n_agents = n_agents
        self.unitperlayer = 40
        self.K = K
        self.M = 5  ## no of betas to calculate misreported peaks
        self.fc1 = nn.Linear(self.n_agents,self.unitperlayer)
        self.fc2 = nn.Linear(self.unitperlayer,self.unitperlayer)
        self.fc3 = nn.Linear(self.unitperlayer,self.unitperlayer)
        self.fc4 = nn.Linear(self.unitperlayer,self.unitperlayer)
        self.fc5 = nn.Linear(self.unitperlayer,self.K)
        torch.nn.init.uniform_(self.fc1.weight, a=0.0, b=0.01)
        self.fc1.bias.data.fill_(0.1)
        torch.nn.init.uniform_(self.fc2.weight, a=0.0, b=0.01)
        self.fc2.bias.data.fill_(0.1)
        torch.nn.init.uniform_(self.fc3.weight, a=0.0, b=0.01)
        self.fc3.bias.data.fill_(0.1)
        torch.nn.init.uniform_(self.fc4.weight, a=0.0, b=0.01)
        self.fc4.bias.data.fill_(0.1)
        torch.nn.init.uniform_(self.fc5.weight, a=0.0, b=0.01)
        self.fc5.bias.data.fill_(0.1)

    def forward(self, x):
      x = F.relu(self.fc1(x))
      x = F.relu(self.fc2(x))
      x = F.relu(self.fc3(x))
      x = F.relu(self.fc4(x))
      x = F.relu(self.fc5(x))
      return x

    def calculateUtility(self,peak_arr, output):
        ## for agent i, peaks of all datasampes
        ## peak_arr :  n_samples x 1
        ### output : n_samples x K
        loss = torch.tensor([])
        if use_cuda:
          loss = loss.cuda()

        ## For each facility calcuate loss
        for k in range(self.K):        
          k_facility_location = output[k:k+1]
          appendloss = torch.add(peak_arr,-k_facility_location)    
          loss  = torch.cat([loss,appendloss ], axis = 0)
        loss = torch.abs(loss)
        loss = torch.reshape(loss, (self.K,self.n_agents) )
        ## take minimum loss amoung all k facility i.e. loss corresponding to closest facility to peak
        loss , indices = torch.min(loss, axis=0)
        utility = -loss
        return utility
    
    def calculateRegret(self,y,x, betas):
      ## y : is output location of K facility for all n_samples  n_samples x K
      ### x is n_samples x n_agents (peaks of data)
      ### betas - that are sampled to calculate regret
      ### we will calculate regret only if a peak matches any of betas, and then misreported peaks becomes rest of the betas
      ## Examples if betas is [0.2 , 0.4, 0.6, 0.8 , 1]
      ## and peak is [0.4] then you go ahead and find regret with misreported values [0.2,0.6,0.8,1]
      ## For practicality, we keep a threshold , instead of fully matching betas and peaks

      ## From the paper 
      ### For each example j, (5) computes the maximum utility agent i could gain if her true peak was one
      ### of β1;...; βM and she chose to misreport it as one of β1,..., βM.

      regret = []
      threshold = 0.01
      ## For each agent
      for i in range(self.n_agents):
        ## fetch their peaks
        peak_of_agent_i = x[ :, i:i+1]
        count = 0
        regret_for_agent_i = []

        ## For each peak, 
        for j, peak in enumerate(peak_of_agent_i):
          valuedifference = torch.add(betas, -peak)
          isValuePresentWithThreshold = torch.abs(valuedifference) <= threshold
          ## Find if peak matches any value in betas
          if True in isValuePresentWithThreshold:
            count += 1
            index =  torch.where(isValuePresentWithThreshold == True)
            ## to calucate regret
            regret_for_an_sample = []

            ## calculate regret for all other values of betas 
            for b in range(self.M):
              if( b != index[0][0]):
                datasample = x[j].clone()
                
                ## misreported output location Kx1
                misreporteddatasample = datasample.clone()
                misreporteddatasample[i] = betas[b]
                misrerpoted_output = self.forward(misreporteddatasample)
                
                ## acutal output location K x 1
                actualdatasample = datasample.clone()
                actualdatasample[i] = betas[index[0][0]]
                actualdata_output = self.forward(actualdatasample)

                ## utility will be calcuated considering the actual peak 1x1
                misreported_utility = self.calculateUtility(actualdatasample,misrerpoted_output)
                actual_utility = self.calculateUtility(actualdatasample,actualdata_output)

                difference_for_agent_i = misreported_utility[i] -   actual_utility[i]
                regret_for_an_sample.append(difference_for_agent_i)

            regret_for_an_sample = torch.FloatTensor(regret_for_an_sample)
            ## for all the misreported peaks, chose the maximum regret for that sample
            regret_for_an_sample = torch.max(regret_for_an_sample)
            ## append it to the regret of agent 
            regret_for_agent_i.append(regret_for_an_sample)
          else:
            ## when peaks doesnt matches any betas, we simply append 0 peak
            regret_for_agent_i.append(0)
        

        regret_for_agent_i = torch.FloatTensor(regret_for_agent_i)
        # regret_for_an_sample = torch.mean(regret_for_an_sample)
        # taking mean over all samples for agent and append to regret
        regret_for_agent_i = torch.mean(regret_for_agent_i)
        regret.append(regret_for_agent_i)
        print('For agent ' , i , ' no of beta matches with peak', count)
      print('regret is ', regret)

      regret = torch.FloatTensor(regret)
      maxregretamoungagents = torch.max(regret)
      print('max regret amoung agents', maxregretamoungagents)
      return regret, maxregretamoungagents



    def loss_function(self, y, x, _lamdda , _rho):

      ## Betas for calculating regret
      betas =  np.random.rand(self.M)
      betas = torch.FloatTensor(betas)
      if use_cuda:
        betas = betas.cuda()
      print('betas', betas)

      regret , maxregretamoungagents = self.calculateRegret(y,x,betas)

      ## calculatting social cost the same way we did in moulin net
      loss = torch.tensor([]).cuda()
      for k in range(self.K):        
        loss_for_k_facility = y[:,k:k+1]
        appendloss = torch.add(x,-loss_for_k_facility)    
        loss  = torch.cat([loss,appendloss ], axis = 1)
      loss = torch.abs(loss)
      loss = torch.reshape(loss, (x.shape[0],self.K,self.n_agents) )
      loss , indices = torch.min(loss, axis=1)
      loss = torch.mean((torch.sum(  loss , dim=1))/self.n_agents)

      print('social cost ' , loss)

      loss = loss + (maxregretamoungagents * _lamdda) +  ( maxregretamoungagents**2 ) * _rho
      return loss, maxregretamoungagents

# %%
### Train and Testing of Moulin Net

K = 1
net = MoulinNet(n_agents,K)
epochs = 40
learning_rate = 0.1

def moulin_train(X_train,epochs=epochs, learning_rate=learning_rate):
  optimizer = optim.Adam(net.parameters(), lr= learning_rate)
  with torch.autograd.set_detect_anomaly(True):
    for epoch in range(epochs):
        optimizer.zero_grad()
        y_pred = net(X_train)
        train_loss = net.loss_function(y_pred,X_train)    
        print( 'Epoch : ', epoch ,  'training loss ', train_loss)
        train_loss.backward()
        optimizer.step()

def moulin_test(X_test):
    y_test = net(X_test)
    test_loss = net.loss_function(y_test,X_test)    
    print('Testing Loss is ', test_loss)


moulin_train(moulin_train_data)
moulin_test(moulin_test_data)
# Out:
# Epoch :  0 training loss  tensor(0.2438, grad_fn=<MeanBackward0>)
# Epoch :  1 training loss  tensor(0.2357, grad_fn=<MeanBackward0>)
# Epoch :  2 training loss  tensor(0.2308, grad_fn=<MeanBackward0>)
# Epoch :  3 training loss  tensor(0.2071, grad_fn=<MeanBackward0>)
# Epoch :  4 training loss  tensor(0.2018, grad_fn=<MeanBackward0>)
# Epoch :  5 training loss  tensor(0.2002, grad_fn=<MeanBackward0>)
# Epoch :  6 training loss  tensor(0.1995, grad_fn=<MeanBackward0>)
# Epoch :  7 training loss  tensor(0.1993, grad_fn=<MeanBackward0>)
# Epoch :  8 training loss  tensor(0.1990, grad_fn=<MeanBackward0>)
# Epoch :  9 training loss  tensor(0.1985, grad_fn=<MeanBackward0>)
# Epoch :  10 training loss  tensor(0.1982, grad_fn=<MeanBackward0>)
# Epoch :  11 training loss  tensor(0.1977, grad_fn=<MeanBackward0>)
# Epoch :  12 training loss  tensor(0.1973, grad_fn=<MeanBackward0>)
# Epoch :  13 training loss  tensor(0.1971, grad_fn=<MeanBackward0>)
# Epoch :  14 training loss  tensor(0.1970, grad_fn=<MeanBackward0>)
# Epoch :  15 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  16 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  17 training loss  tensor(0.1970, grad_fn=<MeanBackward0>)
# Epoch :  18 training loss  tensor(0.1970, grad_fn=<MeanBackward0>)
# Epoch :  19 training loss  tensor(0.1970, grad_fn=<MeanBackward0>)
# Epoch :  20 training loss  tensor(0.1971, grad_fn=<MeanBackward0>)
# Epoch :  21 training loss  tensor(0.1971, grad_fn=<MeanBackward0>)
# Epoch :  22 training loss  tensor(0.1970, grad_fn=<MeanBackward0>)
# Epoch :  23 training loss  tensor(0.1970, grad_fn=<MeanBackward0>)
# Epoch :  24 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  25 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  26 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  27 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  28 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  29 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  30 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  31 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  32 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  33 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  34 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  35 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  36 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  37 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  38 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Epoch :  39 training loss  tensor(0.1969, grad_fn=<MeanBackward0>)
# Testing Loss is  tensor(0.2013, grad_fn=<MeanBackward0>)

# %%
### Train and Test Regret net
### mini batch training
K = 2
mini_batch_size  = 500
lr = 0.005
epochs = 40
_rho = 0.0005


net = RegretNet(n_agents,K)
if use_cuda:
    net = net.cuda()

def create_mini_batches(data, batch_size): 
    mini_batches = [] 
    indices = np.random.permutation(data.shape[0])
    n_minibatches = data.shape[0] // batch_size   
    for i in range(n_minibatches ): 
        mini_batch_idx= indices[i * batch_size:(i + 1)*batch_size]
        mini_batch = data[ mini_batch_idx, :] 
        mini_batches.append(mini_batch) 
    return mini_batches 


## decay learning rate
def adjust_learning_rate(optimizer, epoch,  no_iterations, quantity, lr= lr):
    lr = lr * (quantity ** (epoch // no_iterations))
    for param_group in optimizer.param_groups:
      param_group['lr'] = lr
      print('current learning rate ', lr)


def regretnet_train(X_train,epochs=epochs, learning_rate=lr, ):

  _lamdda = 0.1
  optimizer = optim.Adam(net.parameters(), lr= learning_rate)
  with torch.autograd.set_detect_anomaly(True):
    for epoch in range(epochs):
        totalerror = []
        minibatches = create_mini_batches(X_train,mini_batch_size )
        for minibatch in minibatches:
          optimizer.zero_grad()
          ## decay lr after some epochs
          adjust_learning_rate(optimizer, epoch, 10, 0.99)

          y_pred = net(minibatch)
          train_loss , maxregret = net.loss_function(y_pred,minibatch,_lamdda,_rho)    

          ## total error for a epoch
          totalerror.append(train_loss)

          train_loss.backward()
          optimizer.step()

          print('Epoch : ', epoch , 'minibatch loss  ', train_loss)
        totalerror = torch.FloatTensor(totalerror)
        print( 'Epoch : ', epoch ,  'training loss ', torch.mean(totalerror))

        ## Update rule for lambda
        if(epoch % 5 == 0):
          print(' current lambda', _lamdda , ' to minus ',  _rho* maxregret)
          _lamdda = _lamdda - _rho* maxregret
          print(' _lamdda value ', _lamdda)
  return _lamdda        



def regretnet_test(X_test):
    y_test = net(X_test)
    test_loss, maxregret = net.loss_function(y_test,X_test,_lamdda,_rho)
    print('Testing Loss is ', test_loss)
    print('max regret is ', maxregret)


_lamdda = regretnet_train(regretnet_train_data.cuda())
regretnet_test(regretnet_test_data.cuda())
#
# Out:
# current learning rate  0.005
# betas tensor([0.5149, 0.2408, 0.2894, 0.6870, 0.9669], device='cuda:0')
# For agent  0  no of beta matches with peak 51
# For agent  1  no of beta matches with peak 52
# For agent  2  no of beta matches with peak 40
# For agent  3  no of beta matches with peak 43
# For agent  4  no of beta matches with peak 56
# regret is  [tensor(3.2532e-07), tensor(3.2896e-07), tensor(2.4089e-07), tensor(3.2103e-07), tensor(3.6183e-07)]
# max regret amoung agents tensor(3.6183e-07)
# social cost  tensor(0.3924, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  0 minibatch loss   tensor(0.3924, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.8933, 0.2582, 0.1778, 0.0928, 0.9896], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 47
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 47
# For agent  4  no of beta matches with peak 53
# regret is  [tensor(5.5272e-06), tensor(6.5508e-06), tensor(6.5729e-06), tensor(4.6234e-06), tensor(1.0992e-05)]
# max regret amoung agents tensor(1.0992e-05)
# social cost  tensor(0.3430, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  0 minibatch loss   tensor(0.3430, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.0802, 0.9365, 0.1802, 0.3912, 0.2740], device='cuda:0')
# For agent  0  no of beta matches with peak 60
# For agent  1  no of beta matches with peak 48
# For agent  2  no of beta matches with peak 51
# For agent  3  no of beta matches with peak 52
# For agent  4  no of beta matches with peak 49
# regret is  [tensor(2.0859e-05), tensor(2.5599e-05), tensor(1.1754e-05), tensor(1.0309e-05), tensor(2.2900e-05)]
# max regret amoung agents tensor(2.5599e-05)
# social cost  tensor(0.2863, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  0 minibatch loss   tensor(0.2863, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  0 training loss  tensor(0.3406)
#  current lambda 0.1  to minus  tensor(1.2799e-08)
#  _lamdda value  tensor(0.1000)
# current learning rate  0.005
# betas tensor([0.4617, 0.3683, 0.5362, 0.1724, 0.0246], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 49
# For agent  2  no of beta matches with peak 53
# For agent  3  no of beta matches with peak 42
# For agent  4  no of beta matches with peak 48
# regret is  [tensor(4.3895e-05), tensor(3.1703e-05), tensor(3.8946e-05), tensor(3.1535e-05), tensor(3.2059e-05)]
# max regret amoung agents tensor(4.3895e-05)
# social cost  tensor(0.2196, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  1 minibatch loss   tensor(0.2196, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.7519, 0.8938, 0.5023, 0.4416, 0.2631], device='cuda:0')
# For agent  0  no of beta matches with peak 43
# For agent  1  no of beta matches with peak 49
# For agent  2  no of beta matches with peak 56
# For agent  3  no of beta matches with peak 57
# For agent  4  no of beta matches with peak 44
# regret is  [tensor(0.0002), tensor(0.0001), tensor(0.0002), tensor(9.0374e-05), tensor(0.0001)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1635, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  1 minibatch loss   tensor(0.1636, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.6218, 0.6729, 0.2249, 0.0219, 0.4366], device='cuda:0')
# For agent  0  no of beta matches with peak 58
# For agent  1  no of beta matches with peak 39
# For agent  2  no of beta matches with peak 60
# For agent  3  no of beta matches with peak 55
# For agent  4  no of beta matches with peak 47
# regret is  [tensor(0.0012), tensor(0.0008), tensor(0.0010), tensor(0.0012), tensor(0.0011)]
# max regret amoung agents tensor(0.0012)
# social cost  tensor(0.1812, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  1 minibatch loss   tensor(0.1814, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  1 training loss  tensor(0.1882)
# current learning rate  0.005
# betas tensor([0.7612, 0.2844, 0.1879, 0.9928, 0.1856], device='cuda:0')
# For agent  0  no of beta matches with peak 31
# For agent  1  no of beta matches with peak 36
# For agent  2  no of beta matches with peak 46
# For agent  3  no of beta matches with peak 43
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(0.0004), tensor(0.0005), tensor(0.0005), tensor(0.0004), tensor(0.0004)]
# max regret amoung agents tensor(0.0005)
# social cost  tensor(0.1637, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  2 minibatch loss   tensor(0.1637, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.3560, 0.8228, 0.7039, 0.7767, 0.4813], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 39
# For agent  3  no of beta matches with peak 50
# For agent  4  no of beta matches with peak 56
# regret is  [tensor(0.0006), tensor(0.0005), tensor(0.0005), tensor(0.0007), tensor(0.0008)]
# max regret amoung agents tensor(0.0008)
# social cost  tensor(0.1282, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  2 minibatch loss   tensor(0.1283, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.3496, 0.8367, 0.9254, 0.7118, 0.8056], device='cuda:0')
# For agent  0  no of beta matches with peak 48
# For agent  1  no of beta matches with peak 51
# For agent  2  no of beta matches with peak 56
# For agent  3  no of beta matches with peak 57
# For agent  4  no of beta matches with peak 42
# regret is  [tensor(0.0002), tensor(0.0001), tensor(0.0002), tensor(0.0002), tensor(0.0002)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1312, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  2 minibatch loss   tensor(0.1312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  2 training loss  tensor(0.1411)
# current learning rate  0.005
# betas tensor([0.6372, 0.5541, 0.8862, 0.7295, 0.1266], device='cuda:0')
# For agent  0  no of beta matches with peak 39
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 47
# For agent  3  no of beta matches with peak 61
# For agent  4  no of beta matches with peak 47
# regret is  [tensor(7.6629e-05), tensor(0.0002), tensor(0.0002), tensor(0.0002), tensor(8.7105e-05)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1439, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  3 minibatch loss   tensor(0.1440, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.9796, 0.6784, 0.7241, 0.9954, 0.3163], device='cuda:0')
# For agent  0  no of beta matches with peak 39
# For agent  1  no of beta matches with peak 50
# For agent  2  no of beta matches with peak 39
# For agent  3  no of beta matches with peak 42
# For agent  4  no of beta matches with peak 52
# regret is  [tensor(7.7161e-05), tensor(0.0001), tensor(8.4698e-05), tensor(0.0001), tensor(0.0001)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1546, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  3 minibatch loss   tensor(0.1546, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.2826, 0.2062, 0.2973, 0.4070, 0.9241], device='cuda:0')
# For agent  0  no of beta matches with peak 58
# For agent  1  no of beta matches with peak 47
# For agent  2  no of beta matches with peak 47
# For agent  3  no of beta matches with peak 55
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(-0.0001), tensor(-3.2720e-05), tensor(5.2593e-06), tensor(-8.6743e-05), tensor(-5.5845e-05)]
# max regret amoung agents tensor(5.2593e-06)
# social cost  tensor(0.1531, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  3 minibatch loss   tensor(0.1531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  3 training loss  tensor(0.1506)
# current learning rate  0.005
# betas tensor([0.5923, 0.5158, 0.2521, 0.9457, 0.3302], device='cuda:0')
# For agent  0  no of beta matches with peak 47
# For agent  1  no of beta matches with peak 41
# For agent  2  no of beta matches with peak 56
# For agent  3  no of beta matches with peak 41
# For agent  4  no of beta matches with peak 38
# regret is  [tensor(8.2654e-05), tensor(-7.7035e-06), tensor(1.1185e-05), tensor(1.2922e-05), tensor(4.1191e-05)]
# max regret amoung agents tensor(8.2654e-05)
# social cost  tensor(0.1476, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  4 minibatch loss   tensor(0.1477, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.2214, 0.9155, 0.9514, 0.2320, 0.7819], device='cuda:0')
# For agent  0  no of beta matches with peak 56
# For agent  1  no of beta matches with peak 42
# For agent  2  no of beta matches with peak 43
# For agent  3  no of beta matches with peak 47
# For agent  4  no of beta matches with peak 33
# regret is  [tensor(3.6251e-05), tensor(1.6449e-05), tensor(2.2063e-05), tensor(4.7706e-05), tensor(1.7332e-05)]
# max regret amoung agents tensor(4.7706e-05)
# social cost  tensor(0.1422, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  4 minibatch loss   tensor(0.1422, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.8380, 0.0553, 0.5351, 0.5170, 0.7542], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 50
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 38
# For agent  4  no of beta matches with peak 40
# regret is  [tensor(0.0001), tensor(0.0001), tensor(0.0002), tensor(8.6443e-05), tensor(0.0001)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1300, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  4 minibatch loss   tensor(0.1300, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  4 training loss  tensor(0.1400)
# current learning rate  0.005
# betas tensor([0.0085, 0.9898, 0.9243, 0.2627, 0.8000], device='cuda:0')
# For agent  0  no of beta matches with peak 60
# For agent  1  no of beta matches with peak 40
# For agent  2  no of beta matches with peak 53
# For agent  3  no of beta matches with peak 51
# For agent  4  no of beta matches with peak 49
# regret is  [tensor(4.4122e-05), tensor(3.5769e-05), tensor(5.1946e-05), tensor(4.7777e-05), tensor(5.4698e-05)]
# max regret amoung agents tensor(5.4698e-05)
# social cost  tensor(0.1271, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  5 minibatch loss   tensor(0.1271, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.9454, 0.9668, 0.6202, 0.6222, 0.3205], device='cuda:0')
# For agent  0  no of beta matches with peak 37
# For agent  1  no of beta matches with peak 39
# For agent  2  no of beta matches with peak 52
# For agent  3  no of beta matches with peak 40
# For agent  4  no of beta matches with peak 31
# regret is  [tensor(0.0002), tensor(0.0001), tensor(0.0002), tensor(0.0002), tensor(0.0001)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1256, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  5 minibatch loss   tensor(0.1256, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.2427, 0.3009, 0.6364, 0.6472, 0.1431], device='cuda:0')
# For agent  0  no of beta matches with peak 38
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 39
# For agent  3  no of beta matches with peak 49
# For agent  4  no of beta matches with peak 43
# regret is  [tensor(0.0002), tensor(0.0003), tensor(0.0002), tensor(0.0003), tensor(0.0002)]
# max regret amoung agents tensor(0.0003)
# social cost  tensor(0.1313, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  5 minibatch loss   tensor(0.1313, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  5 training loss  tensor(0.1280)
#  current lambda tensor(0.1000)  to minus  tensor(1.6281e-07)
#  _lamdda value  tensor(0.1000)
# current learning rate  0.005
# betas tensor([0.9109, 0.3741, 0.1885, 0.9394, 0.6687], device='cuda:0')
# For agent  0  no of beta matches with peak 51
# For agent  1  no of beta matches with peak 49
# For agent  2  no of beta matches with peak 47
# For agent  3  no of beta matches with peak 52
# For agent  4  no of beta matches with peak 41
# regret is  [tensor(0.0001), tensor(0.0001), tensor(0.0001), tensor(0.0001), tensor(7.4194e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1296, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  6 minibatch loss   tensor(0.1297, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.8921, 0.9789, 0.2152, 0.2033, 0.3994], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 47
# For agent  2  no of beta matches with peak 57
# For agent  3  no of beta matches with peak 59
# For agent  4  no of beta matches with peak 43
# regret is  [tensor(5.9147e-05), tensor(5.2071e-05), tensor(5.9734e-05), tensor(6.3066e-05), tensor(3.4975e-05)]
# max regret amoung agents tensor(6.3066e-05)
# social cost  tensor(0.1306, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  6 minibatch loss   tensor(0.1306, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.7489, 0.6701, 0.8912, 0.4833, 0.4779], device='cuda:0')
# For agent  0  no of beta matches with peak 38
# For agent  1  no of beta matches with peak 43
# For agent  2  no of beta matches with peak 39
# For agent  3  no of beta matches with peak 46
# For agent  4  no of beta matches with peak 34
# regret is  [tensor(9.2056e-05), tensor(9.8507e-05), tensor(7.1340e-05), tensor(8.6244e-05), tensor(5.8169e-05)]
# max regret amoung agents tensor(9.8507e-05)
# social cost  tensor(0.1297, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  6 minibatch loss   tensor(0.1297, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  6 training loss  tensor(0.1300)
# current learning rate  0.005
# betas tensor([0.5161, 0.9113, 0.0912, 0.3997, 0.6990], device='cuda:0')
# For agent  0  no of beta matches with peak 49
# For agent  1  no of beta matches with peak 45
# For agent  2  no of beta matches with peak 41
# For agent  3  no of beta matches with peak 52
# For agent  4  no of beta matches with peak 49
# regret is  [tensor(5.7763e-05), tensor(0.0002), tensor(0.0001), tensor(0.0001), tensor(0.0001)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1272, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  7 minibatch loss   tensor(0.1272, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.9833, 0.8189, 0.8364, 0.6205, 0.4039], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 46
# For agent  2  no of beta matches with peak 56
# For agent  3  no of beta matches with peak 52
# For agent  4  no of beta matches with peak 43
# regret is  [tensor(5.4453e-05), tensor(4.7309e-05), tensor(4.5249e-05), tensor(5.3662e-05), tensor(4.1272e-05)]
# max regret amoung agents tensor(5.4453e-05)
# social cost  tensor(0.1295, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  7 minibatch loss   tensor(0.1295, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.9814, 0.6834, 0.4991, 0.9901, 0.4553], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 51
# For agent  2  no of beta matches with peak 49
# For agent  3  no of beta matches with peak 54
# For agent  4  no of beta matches with peak 43
# regret is  [tensor(1.2565e-05), tensor(2.6534e-05), tensor(2.2555e-05), tensor(2.8164e-05), tensor(1.4862e-05)]
# max regret amoung agents tensor(2.8164e-05)
# social cost  tensor(0.1286, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  7 minibatch loss   tensor(0.1286, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  7 training loss  tensor(0.1284)
# current learning rate  0.005
# betas tensor([0.8118, 0.9962, 0.9823, 0.8552, 0.2497], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 43
# For agent  2  no of beta matches with peak 38
# For agent  3  no of beta matches with peak 50
# For agent  4  no of beta matches with peak 47
# regret is  [tensor(4.7064e-05), tensor(4.7285e-05), tensor(3.1149e-05), tensor(5.0682e-05), tensor(4.7301e-05)]
# max regret amoung agents tensor(5.0682e-05)
# social cost  tensor(0.1290, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  8 minibatch loss   tensor(0.1290, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.6495, 0.1688, 0.9322, 0.7624, 0.8984], device='cuda:0')
# For agent  0  no of beta matches with peak 43
# For agent  1  no of beta matches with peak 43
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 46
# For agent  4  no of beta matches with peak 50
# regret is  [tensor(5.0556e-05), tensor(4.4005e-05), tensor(4.8212e-05), tensor(5.7785e-05), tensor(3.3540e-05)]
# max regret amoung agents tensor(5.7785e-05)
# social cost  tensor(0.1302, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  8 minibatch loss   tensor(0.1302, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.6209, 0.8531, 0.6242, 0.1442, 0.5806], device='cuda:0')
# For agent  0  no of beta matches with peak 41
# For agent  1  no of beta matches with peak 36
# For agent  2  no of beta matches with peak 46
# For agent  3  no of beta matches with peak 45
# For agent  4  no of beta matches with peak 40
# regret is  [tensor(7.4838e-05), tensor(5.1727e-05), tensor(5.8027e-05), tensor(8.8491e-05), tensor(6.6053e-05)]
# max regret amoung agents tensor(8.8491e-05)
# social cost  tensor(0.1302, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  8 minibatch loss   tensor(0.1302, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  8 training loss  tensor(0.1298)
# current learning rate  0.005
# betas tensor([0.3774, 0.3194, 0.1596, 0.6800, 0.6150], device='cuda:0')
# For agent  0  no of beta matches with peak 50
# For agent  1  no of beta matches with peak 69
# For agent  2  no of beta matches with peak 46
# For agent  3  no of beta matches with peak 45
# For agent  4  no of beta matches with peak 45
# regret is  [tensor(0.0001), tensor(0.0001), tensor(0.0001), tensor(9.3437e-05), tensor(8.0825e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1287, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  9 minibatch loss   tensor(0.1287, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.7587, 0.6975, 0.6197, 0.4074, 0.9609], device='cuda:0')
# For agent  0  no of beta matches with peak 39
# For agent  1  no of beta matches with peak 56
# For agent  2  no of beta matches with peak 50
# For agent  3  no of beta matches with peak 41
# For agent  4  no of beta matches with peak 37
# regret is  [tensor(4.6571e-05), tensor(0.0001), tensor(7.9961e-05), tensor(6.3881e-05), tensor(6.3669e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1236, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  9 minibatch loss   tensor(0.1237, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.005
# betas tensor([0.6121, 0.5837, 0.2977, 0.7740, 0.2218], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 46
# For agent  3  no of beta matches with peak 49
# For agent  4  no of beta matches with peak 51
# regret is  [tensor(7.2726e-05), tensor(0.0001), tensor(6.7837e-05), tensor(6.2697e-05), tensor(6.7542e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1243, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  9 minibatch loss   tensor(0.1243, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  9 training loss  tensor(0.1256)
# current learning rate  0.00495
# betas tensor([0.9913, 0.8229, 0.1168, 0.0043, 0.1929], device='cuda:0')
# For agent  0  no of beta matches with peak 49
# For agent  1  no of beta matches with peak 35
# For agent  2  no of beta matches with peak 50
# For agent  3  no of beta matches with peak 68
# For agent  4  no of beta matches with peak 54
# regret is  [tensor(5.1191e-06), tensor(2.1074e-05), tensor(1.0135e-05), tensor(7.4194e-06), tensor(9.5742e-06)]
# max regret amoung agents tensor(2.1074e-05)
# social cost  tensor(0.1234, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  10 minibatch loss   tensor(0.1234, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.8023, 0.5738, 0.0163, 0.8228, 0.0711], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 52
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 55
# For agent  4  no of beta matches with peak 53
# regret is  [tensor(0.0001), tensor(0.0002), tensor(0.0002), tensor(0.0002), tensor(0.0002)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1268, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  10 minibatch loss   tensor(0.1269, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.6244, 0.7284, 0.8077, 0.8474, 0.7855], device='cuda:0')
# For agent  0  no of beta matches with peak 54
# For agent  1  no of beta matches with peak 60
# For agent  2  no of beta matches with peak 58
# For agent  3  no of beta matches with peak 49
# For agent  4  no of beta matches with peak 55
# regret is  [tensor(5.4278e-05), tensor(6.1849e-05), tensor(6.3121e-05), tensor(4.1465e-05), tensor(4.1348e-05)]
# max regret amoung agents tensor(6.3121e-05)
# social cost  tensor(0.1286, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  10 minibatch loss   tensor(0.1286, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  10 training loss  tensor(0.1263)
#  current lambda tensor(0.1000)  to minus  tensor(3.1561e-08)
#  _lamdda value  tensor(0.1000)
# current learning rate  0.00495
# betas tensor([0.5015, 0.0449, 0.2464, 0.3592, 0.1826], device='cuda:0')
# For agent  0  no of beta matches with peak 42
# For agent  1  no of beta matches with peak 39
# For agent  2  no of beta matches with peak 47
# For agent  3  no of beta matches with peak 54
# For agent  4  no of beta matches with peak 50
# regret is  [tensor(3.8370e-06), tensor(1.2099e-05), tensor(6.2988e-06), tensor(9.2509e-06), tensor(9.6937e-06)]
# max regret amoung agents tensor(1.2099e-05)
# social cost  tensor(0.1270, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  11 minibatch loss   tensor(0.1270, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.3786, 0.5031, 0.8468, 0.8845, 0.9138], device='cuda:0')
# For agent  0  no of beta matches with peak 57
# For agent  1  no of beta matches with peak 49
# For agent  2  no of beta matches with peak 59
# For agent  3  no of beta matches with peak 57
# For agent  4  no of beta matches with peak 47
# regret is  [tensor(6.4913e-05), tensor(4.8627e-05), tensor(4.9101e-05), tensor(5.0196e-05), tensor(4.4257e-05)]
# max regret amoung agents tensor(6.4913e-05)
# social cost  tensor(0.1263, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  11 minibatch loss   tensor(0.1263, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.2286, 0.8131, 0.9260, 0.1114, 0.6070], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 58
# For agent  2  no of beta matches with peak 53
# For agent  3  no of beta matches with peak 50
# For agent  4  no of beta matches with peak 56
# regret is  [tensor(6.4498e-05), tensor(0.0001), tensor(7.8228e-05), tensor(6.1459e-05), tensor(5.2375e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1239, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  11 minibatch loss   tensor(0.1239, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  11 training loss  tensor(0.1257)
# current learning rate  0.00495
# betas tensor([0.5034, 0.5706, 0.9793, 0.8179, 0.5560], device='cuda:0')
# For agent  0  no of beta matches with peak 36
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 55
# For agent  3  no of beta matches with peak 51
# For agent  4  no of beta matches with peak 52
# regret is  [tensor(1.6179e-05), tensor(4.1981e-05), tensor(2.6610e-05), tensor(2.9178e-05), tensor(2.6276e-05)]
# max regret amoung agents tensor(4.1981e-05)
# social cost  tensor(0.1255, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  12 minibatch loss   tensor(0.1255, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([3.1161e-01, 5.4774e-01, 2.3160e-04, 9.2076e-01, 2.7676e-01],
#        device='cuda:0')
# For agent  0  no of beta matches with peak 51
# For agent  1  no of beta matches with peak 42
# For agent  2  no of beta matches with peak 45
# For agent  3  no of beta matches with peak 42
# For agent  4  no of beta matches with peak 47
# regret is  [tensor(6.3269e-05), tensor(8.7726e-05), tensor(2.6456e-05), tensor(-1.0725e-06), tensor(3.4459e-05)]
# max regret amoung agents tensor(8.7726e-05)
# social cost  tensor(0.1257, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  12 minibatch loss   tensor(0.1257, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.7075, 0.2301, 0.8290, 0.9931, 0.4076], device='cuda:0')
# For agent  0  no of beta matches with peak 50
# For agent  1  no of beta matches with peak 40
# For agent  2  no of beta matches with peak 43
# For agent  3  no of beta matches with peak 47
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(5.1817e-05), tensor(5.6359e-05), tensor(5.0851e-05), tensor(6.3229e-05), tensor(7.1024e-05)]
# max regret amoung agents tensor(7.1024e-05)
# social cost  tensor(0.1268, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  12 minibatch loss   tensor(0.1268, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  12 training loss  tensor(0.1260)
# current learning rate  0.00495
# betas tensor([0.9057, 0.3958, 0.4213, 0.3609, 0.6068], device='cuda:0')
# For agent  0  no of beta matches with peak 59
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 53
# For agent  3  no of beta matches with peak 55
# For agent  4  no of beta matches with peak 44
# regret is  [tensor(5.5295e-05), tensor(4.6770e-05), tensor(4.5140e-05), tensor(3.7430e-05), tensor(5.3653e-05)]
# max regret amoung agents tensor(5.5295e-05)
# social cost  tensor(0.1257, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  13 minibatch loss   tensor(0.1257, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.3565, 0.1060, 0.2678, 0.1518, 0.3735], device='cuda:0')
# For agent  0  no of beta matches with peak 57
# For agent  1  no of beta matches with peak 48
# For agent  2  no of beta matches with peak 50
# For agent  3  no of beta matches with peak 43
# For agent  4  no of beta matches with peak 52
# regret is  [tensor(2.7266e-06), tensor(3.7021e-06), tensor(3.0657e-06), tensor(4.1526e-06), tensor(3.5530e-06)]
# max regret amoung agents tensor(4.1526e-06)
# social cost  tensor(0.1242, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  13 minibatch loss   tensor(0.1242, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.4833, 0.7037, 0.9167, 0.0349, 0.9598], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 49
# For agent  2  no of beta matches with peak 52
# For agent  3  no of beta matches with peak 44
# For agent  4  no of beta matches with peak 50
# regret is  [tensor(6.5724e-05), tensor(8.9470e-05), tensor(9.7848e-05), tensor(0.0001), tensor(9.6659e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1266, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  13 minibatch loss   tensor(0.1266, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  13 training loss  tensor(0.1255)
# current learning rate  0.00495
# betas tensor([0.1372, 0.6827, 0.0031, 0.4674, 0.5645], device='cuda:0')
# For agent  0  no of beta matches with peak 60
# For agent  1  no of beta matches with peak 53
# For agent  2  no of beta matches with peak 43
# For agent  3  no of beta matches with peak 54
# For agent  4  no of beta matches with peak 48
# regret is  [tensor(0.0002), tensor(0.0002), tensor(0.0002), tensor(0.0001), tensor(0.0002)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1259, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  14 minibatch loss   tensor(0.1259, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.7854, 0.1556, 0.7877, 0.2985, 0.1599], device='cuda:0')
# For agent  0  no of beta matches with peak 30
# For agent  1  no of beta matches with peak 21
# For agent  2  no of beta matches with peak 36
# For agent  3  no of beta matches with peak 29
# For agent  4  no of beta matches with peak 39
# regret is  [tensor(2.0219e-05), tensor(1.2957e-05), tensor(2.0787e-05), tensor(1.1642e-05), tensor(2.2355e-05)]
# max regret amoung agents tensor(2.2355e-05)
# social cost  tensor(0.1244, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  14 minibatch loss   tensor(0.1244, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.4326, 0.6714, 0.4326, 0.3347, 0.9649], device='cuda:0')
# For agent  0  no of beta matches with peak 41
# For agent  1  no of beta matches with peak 28
# For agent  2  no of beta matches with peak 49
# For agent  3  no of beta matches with peak 34
# For agent  4  no of beta matches with peak 34
# regret is  [tensor(1.0282e-05), tensor(1.9797e-05), tensor(8.6654e-05), tensor(4.0851e-05), tensor(3.6771e-05)]
# max regret amoung agents tensor(8.6654e-05)
# social cost  tensor(0.1247, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  14 minibatch loss   tensor(0.1247, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  14 training loss  tensor(0.1250)
# current learning rate  0.00495
# betas tensor([0.3698, 0.5741, 0.5251, 0.1079, 0.3440], device='cuda:0')
# For agent  0  no of beta matches with peak 57
# For agent  1  no of beta matches with peak 48
# For agent  2  no of beta matches with peak 58
# For agent  3  no of beta matches with peak 46
# For agent  4  no of beta matches with peak 51
# regret is  [tensor(9.7909e-05), tensor(0.0001), tensor(0.0002), tensor(0.0001), tensor(0.0002)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1259, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  15 minibatch loss   tensor(0.1259, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.8993, 0.0370, 0.9267, 0.7421, 0.2903], device='cuda:0')
# For agent  0  no of beta matches with peak 53
# For agent  1  no of beta matches with peak 50
# For agent  2  no of beta matches with peak 53
# For agent  3  no of beta matches with peak 61
# For agent  4  no of beta matches with peak 53
# regret is  [tensor(9.4039e-05), tensor(0.0001), tensor(0.0001), tensor(0.0002), tensor(8.9855e-05)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1235, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  15 minibatch loss   tensor(0.1235, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.2890, 0.6539, 0.6392, 0.5525, 0.4853], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 52
# For agent  2  no of beta matches with peak 47
# For agent  3  no of beta matches with peak 44
# For agent  4  no of beta matches with peak 41
# regret is  [tensor(0.0001), tensor(0.0002), tensor(0.0001), tensor(0.0001), tensor(0.0001)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1264, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  15 minibatch loss   tensor(0.1264, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  15 training loss  tensor(0.1253)
#  current lambda tensor(0.1000)  to minus  tensor(7.6332e-08)
#  _lamdda value  tensor(0.1000)
# current learning rate  0.00495
# betas tensor([0.7363, 0.9883, 0.9828, 0.9042, 0.3415], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 45
# For agent  2  no of beta matches with peak 49
# For agent  3  no of beta matches with peak 41
# For agent  4  no of beta matches with peak 51
# regret is  [tensor(0.0001), tensor(0.0001), tensor(0.0001), tensor(7.3742e-05), tensor(0.0001)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1237, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  16 minibatch loss   tensor(0.1237, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.8147, 0.5926, 0.8812, 0.0272, 0.8503], device='cuda:0')
# For agent  0  no of beta matches with peak 59
# For agent  1  no of beta matches with peak 49
# For agent  2  no of beta matches with peak 45
# For agent  3  no of beta matches with peak 48
# For agent  4  no of beta matches with peak 51
# regret is  [tensor(9.3197e-05), tensor(6.2132e-05), tensor(7.6499e-05), tensor(9.5554e-05), tensor(9.3274e-05)]
# max regret amoung agents tensor(9.5554e-05)
# social cost  tensor(0.1261, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  16 minibatch loss   tensor(0.1261, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.8413, 0.3858, 0.0879, 0.3293, 0.3421], device='cuda:0')
# For agent  0  no of beta matches with peak 50
# For agent  1  no of beta matches with peak 47
# For agent  2  no of beta matches with peak 50
# For agent  3  no of beta matches with peak 36
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(-1.6409e-05), tensor(-1.3063e-05), tensor(-5.6249e-05), tensor(-5.9038e-06), tensor(-3.4872e-05)]
# max regret amoung agents tensor(-5.9038e-06)
# social cost  tensor(0.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  16 minibatch loss   tensor(0.1245, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  16 training loss  tensor(0.1248)
# current learning rate  0.00495
# betas tensor([0.5808, 0.1878, 0.8646, 0.3680, 0.8695], device='cuda:0')
# For agent  0  no of beta matches with peak 37
# For agent  1  no of beta matches with peak 46
# For agent  2  no of beta matches with peak 37
# For agent  3  no of beta matches with peak 30
# For agent  4  no of beta matches with peak 38
# regret is  [tensor(5.3416e-05), tensor(8.3209e-05), tensor(4.2502e-05), tensor(5.8100e-05), tensor(4.9302e-05)]
# max regret amoung agents tensor(8.3209e-05)
# social cost  tensor(0.1266, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  17 minibatch loss   tensor(0.1266, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.4469, 0.7206, 0.1764, 0.6260, 0.9641], device='cuda:0')
# For agent  0  no of beta matches with peak 44
# For agent  1  no of beta matches with peak 48
# For agent  2  no of beta matches with peak 55
# For agent  3  no of beta matches with peak 46
# For agent  4  no of beta matches with peak 47
# regret is  [tensor(9.1002e-05), tensor(0.0002), tensor(0.0002), tensor(0.0002), tensor(8.6185e-05)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1238, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  17 minibatch loss   tensor(0.1238, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.0068, 0.8741, 0.8160, 0.3682, 0.6826], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 47
# For agent  3  no of beta matches with peak 54
# For agent  4  no of beta matches with peak 43
# regret is  [tensor(7.4224e-05), tensor(0.0001), tensor(0.0001), tensor(9.4747e-05), tensor(0.0001)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1243, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  17 minibatch loss   tensor(0.1244, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  17 training loss  tensor(0.1249)
# current learning rate  0.00495
# betas tensor([0.2676, 0.9589, 0.1746, 0.5622, 0.4534], device='cuda:0')
# For agent  0  no of beta matches with peak 48
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 52
# For agent  3  no of beta matches with peak 49
# For agent  4  no of beta matches with peak 43
# regret is  [tensor(5.5940e-05), tensor(8.4916e-05), tensor(4.3676e-05), tensor(6.9014e-05), tensor(6.6326e-05)]
# max regret amoung agents tensor(8.4916e-05)
# social cost  tensor(0.1268, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  18 minibatch loss   tensor(0.1268, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.3293, 0.8443, 0.4468, 0.7026, 0.9883], device='cuda:0')
# For agent  0  no of beta matches with peak 57
# For agent  1  no of beta matches with peak 41
# For agent  2  no of beta matches with peak 51
# For agent  3  no of beta matches with peak 60
# For agent  4  no of beta matches with peak 53
# regret is  [tensor(0.0001), tensor(0.0001), tensor(9.3413e-05), tensor(0.0001), tensor(0.0001)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1253, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  18 minibatch loss   tensor(0.1254, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.5581, 0.4650, 0.3498, 0.2377, 0.1197], device='cuda:0')
# For agent  0  no of beta matches with peak 48
# For agent  1  no of beta matches with peak 56
# For agent  2  no of beta matches with peak 50
# For agent  3  no of beta matches with peak 50
# For agent  4  no of beta matches with peak 54
# regret is  [tensor(4.8464e-05), tensor(0.0001), tensor(9.6804e-05), tensor(6.1143e-05), tensor(8.3985e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1223, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  18 minibatch loss   tensor(0.1223, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  18 training loss  tensor(0.1248)
# current learning rate  0.00495
# betas tensor([0.5833, 0.6181, 0.6389, 0.4901, 0.1786], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 51
# For agent  2  no of beta matches with peak 46
# For agent  3  no of beta matches with peak 47
# For agent  4  no of beta matches with peak 50
# regret is  [tensor(0.0003), tensor(0.0002), tensor(0.0002), tensor(0.0003), tensor(0.0002)]
# max regret amoung agents tensor(0.0003)
# social cost  tensor(0.1259, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  19 minibatch loss   tensor(0.1259, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.5383, 0.8662, 0.9616, 0.1456, 0.0485], device='cuda:0')
# For agent  0  no of beta matches with peak 42
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 47
# For agent  3  no of beta matches with peak 37
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(7.5914e-05), tensor(0.0001), tensor(9.3053e-05), tensor(4.4535e-05), tensor(8.6516e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1264, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  19 minibatch loss   tensor(0.1264, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.00495
# betas tensor([0.1343, 0.3412, 0.3942, 0.8807, 0.6266], device='cuda:0')
# For agent  0  no of beta matches with peak 41
# For agent  1  no of beta matches with peak 50
# For agent  2  no of beta matches with peak 51
# For agent  3  no of beta matches with peak 49
# For agent  4  no of beta matches with peak 57
# regret is  [tensor(3.6584e-05), tensor(0.0001), tensor(0.0001), tensor(0.0001), tensor(0.0001)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1215, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  19 minibatch loss   tensor(0.1216, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  19 training loss  tensor(0.1246)
# current learning rate  0.0049005
# betas tensor([0.1975, 0.4922, 0.1541, 0.1693, 0.3619], device='cuda:0')
# For agent  0  no of beta matches with peak 40
# For agent  1  no of beta matches with peak 42
# For agent  2  no of beta matches with peak 52
# For agent  3  no of beta matches with peak 44
# For agent  4  no of beta matches with peak 50
# regret is  [tensor(3.8441e-06), tensor(4.0354e-06), tensor(7.3648e-06), tensor(-8.1390e-07), tensor(-3.6657e-07)]
# max regret amoung agents tensor(7.3648e-06)
# social cost  tensor(0.1252, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  20 minibatch loss   tensor(0.1252, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.1321, 0.6715, 0.5554, 0.7130, 0.0019], device='cuda:0')
# For agent  0  no of beta matches with peak 39
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 39
# For agent  3  no of beta matches with peak 45
# For agent  4  no of beta matches with peak 40
# regret is  [tensor(0.0002), tensor(0.0003), tensor(0.0004), tensor(0.0003), tensor(0.0004)]
# max regret amoung agents tensor(0.0004)
# social cost  tensor(0.1246, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  20 minibatch loss   tensor(0.1246, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.7048, 0.9839, 0.3715, 0.0222, 0.9371], device='cuda:0')
# For agent  0  no of beta matches with peak 36
# For agent  1  no of beta matches with peak 56
# For agent  2  no of beta matches with peak 58
# For agent  3  no of beta matches with peak 54
# For agent  4  no of beta matches with peak 53
# regret is  [tensor(4.8607e-05), tensor(0.0002), tensor(0.0002), tensor(0.0002), tensor(0.0002)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1234, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  20 minibatch loss   tensor(0.1235, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  20 training loss  tensor(0.1244)
#  current lambda tensor(0.1000)  to minus  tensor(1.1258e-07)
#  _lamdda value  tensor(0.1000)
# current learning rate  0.0049005
# betas tensor([0.8690, 0.5164, 0.3376, 0.8338, 0.9853], device='cuda:0')
# For agent  0  no of beta matches with peak 52
# For agent  1  no of beta matches with peak 41
# For agent  2  no of beta matches with peak 58
# For agent  3  no of beta matches with peak 47
# For agent  4  no of beta matches with peak 54
# regret is  [tensor(0.0001), tensor(9.8768e-05), tensor(0.0001), tensor(9.6738e-05), tensor(0.0001)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1218, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  21 minibatch loss   tensor(0.1218, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.8093, 0.7381, 0.5276, 0.4101, 0.4006], device='cuda:0')
# For agent  0  no of beta matches with peak 33
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 37
# For agent  3  no of beta matches with peak 38
# For agent  4  no of beta matches with peak 48
# regret is  [tensor(7.3039e-05), tensor(0.0001), tensor(0.0001), tensor(0.0001), tensor(0.0001)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1250, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  21 minibatch loss   tensor(0.1250, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.5095, 0.0647, 0.7693, 0.1862, 0.7629], device='cuda:0')
# For agent  0  no of beta matches with peak 41
# For agent  1  no of beta matches with peak 35
# For agent  2  no of beta matches with peak 35
# For agent  3  no of beta matches with peak 41
# For agent  4  no of beta matches with peak 38
# regret is  [tensor(8.5636e-05), tensor(5.9226e-05), tensor(9.7505e-05), tensor(0.0001), tensor(9.1021e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1263, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  21 minibatch loss   tensor(0.1263, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  21 training loss  tensor(0.1244)
# current learning rate  0.0049005
# betas tensor([0.1727, 0.6501, 0.2605, 0.0013, 0.6052], device='cuda:0')
# For agent  0  no of beta matches with peak 53
# For agent  1  no of beta matches with peak 43
# For agent  2  no of beta matches with peak 38
# For agent  3  no of beta matches with peak 29
# For agent  4  no of beta matches with peak 51
# regret is  [tensor(0.0005), tensor(0.0003), tensor(0.0003), tensor(0.0002), tensor(0.0004)]
# max regret amoung agents tensor(0.0005)
# social cost  tensor(0.1233, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  22 minibatch loss   tensor(0.1233, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.9675, 0.7440, 0.8182, 0.4752, 0.7341], device='cuda:0')
# For agent  0  no of beta matches with peak 40
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 41
# For agent  3  no of beta matches with peak 41
# For agent  4  no of beta matches with peak 32
# regret is  [tensor(0.0001), tensor(0.0001), tensor(7.8372e-05), tensor(0.0001), tensor(9.6303e-05)]
# max regret amoung agents tensor(0.0001)
# social cost  tensor(0.1249, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  22 minibatch loss   tensor(0.1250, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.2113, 0.4099, 0.6689, 0.5403, 0.0728], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 37
# For agent  3  no of beta matches with peak 49
# For agent  4  no of beta matches with peak 40
# regret is  [tensor(0.0003), tensor(0.0003), tensor(0.0002), tensor(0.0003), tensor(0.0002)]
# max regret amoung agents tensor(0.0003)
# social cost  tensor(0.1246, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  22 minibatch loss   tensor(0.1246, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  22 training loss  tensor(0.1243)
# current learning rate  0.0049005
# betas tensor([0.5140, 0.6499, 0.8095, 0.1851, 0.6143], device='cuda:0')
# For agent  0  no of beta matches with peak 45
# For agent  1  no of beta matches with peak 46
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 30
# For agent  4  no of beta matches with peak 59
# regret is  [tensor(0.0002), tensor(0.0002), tensor(0.0002), tensor(0.0001), tensor(0.0004)]
# max regret amoung agents tensor(0.0004)
# social cost  tensor(0.1231, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  23 minibatch loss   tensor(0.1231, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.2175, 0.3606, 0.0799, 0.6986, 0.9306], device='cuda:0')
# For agent  0  no of beta matches with peak 52
# For agent  1  no of beta matches with peak 43
# For agent  2  no of beta matches with peak 51
# For agent  3  no of beta matches with peak 49
# For agent  4  no of beta matches with peak 50
# regret is  [tensor(8.2972e-05), tensor(2.4871e-05), tensor(8.1435e-05), tensor(0.0002), tensor(0.0001)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1248, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  23 minibatch loss   tensor(0.1248, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.4995, 0.7813, 0.4279, 0.6998, 0.5885], device='cuda:0')
# For agent  0  no of beta matches with peak 40
# For agent  1  no of beta matches with peak 55
# For agent  2  no of beta matches with peak 52
# For agent  3  no of beta matches with peak 46
# For agent  4  no of beta matches with peak 49
# regret is  [tensor(0.0001), tensor(0.0002), tensor(0.0002), tensor(7.4626e-05), tensor(0.0001)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1247, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  23 minibatch loss   tensor(0.1248, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  23 training loss  tensor(0.1242)
# current learning rate  0.0049005
# betas tensor([0.4125, 0.8967, 0.0212, 0.8889, 0.1960], device='cuda:0')
# For agent  0  no of beta matches with peak 51
# For agent  1  no of beta matches with peak 38
# For agent  2  no of beta matches with peak 55
# For agent  3  no of beta matches with peak 54
# For agent  4  no of beta matches with peak 58
# regret is  [tensor(3.2216e-05), tensor(3.0109e-05), tensor(5.6477e-05), tensor(5.3689e-05), tensor(5.0732e-05)]
# max regret amoung agents tensor(5.6477e-05)
# social cost  tensor(0.1244, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  24 minibatch loss   tensor(0.1244, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.0049005
# betas tensor([0.3598, 0.1318, 0.9686, 0.6677, 0.4104], device='cuda:0')
# For agent  0  no of beta matches with peak 49
# For agent  1  no of beta matches with peak 57
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 52
# ...
# For agent  0  no of beta matches with peak 58
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 53
# For agent  3  no of beta matches with peak 44
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(0.0007), tensor(0.0007), tensor(0.0006), tensor(0.0005), tensor(0.0007)]
# max regret amoung agents tensor(0.0007)
# social cost  tensor(0.1215, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  32 minibatch loss   tensor(0.1215, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.0798, 0.1918, 0.8994, 0.9765, 0.1086], device='cuda:0')
# For agent  0  no of beta matches with peak 55
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 61
# For agent  3  no of beta matches with peak 54
# For agent  4  no of beta matches with peak 65
# regret is  [tensor(2.2233e-05), tensor(2.1931e-05), tensor(5.0600e-05), tensor(6.5002e-05), tensor(4.2940e-05)]
# max regret amoung agents tensor(6.5002e-05)
# social cost  tensor(0.1233, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  32 minibatch loss   tensor(0.1233, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.5067, 0.1130, 0.2215, 0.9295, 0.2406], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 51
# For agent  2  no of beta matches with peak 53
# For agent  3  no of beta matches with peak 61
# For agent  4  no of beta matches with peak 48
# regret is  [tensor(-2.8337e-05), tensor(2.7880e-05), tensor(-0.0002), tensor(-0.0002), tensor(-0.0002)]
# max regret amoung agents tensor(2.7880e-05)
# social cost  tensor(0.1244, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  32 minibatch loss   tensor(0.1244, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  32 training loss  tensor(0.1231)
# current learning rate  0.004851495
# betas tensor([0.6589, 0.1952, 0.5730, 0.6556, 0.1802], device='cuda:0')
# For agent  0  no of beta matches with peak 40
# For agent  1  no of beta matches with peak 39
# For agent  2  no of beta matches with peak 33
# For agent  3  no of beta matches with peak 40
# For agent  4  no of beta matches with peak 37
# regret is  [tensor(0.0006), tensor(0.0007), tensor(0.0006), tensor(0.0005), tensor(0.0006)]
# max regret amoung agents tensor(0.0007)
# social cost  tensor(0.1207, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  33 minibatch loss   tensor(0.1207, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.1549, 0.5410, 0.6568, 0.4950, 0.1150], device='cuda:0')
# For agent  0  no of beta matches with peak 53
# For agent  1  no of beta matches with peak 30
# For agent  2  no of beta matches with peak 51
# For agent  3  no of beta matches with peak 44
# For agent  4  no of beta matches with peak 55
# regret is  [tensor(0.0009), tensor(0.0005), tensor(0.0008), tensor(0.0005), tensor(0.0007)]
# max regret amoung agents tensor(0.0009)
# social cost  tensor(0.1234, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  33 minibatch loss   tensor(0.1235, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.9582, 0.1745, 0.3311, 0.7478, 0.3409], device='cuda:0')
# For agent  0  no of beta matches with peak 44
# For agent  1  no of beta matches with peak 38
# For agent  2  no of beta matches with peak 52
# For agent  3  no of beta matches with peak 37
# For agent  4  no of beta matches with peak 51
# regret is  [tensor(0.0002), tensor(0.0001), tensor(0.0002), tensor(0.0001), tensor(0.0004)]
# max regret amoung agents tensor(0.0004)
# social cost  tensor(0.1244, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  33 minibatch loss   tensor(0.1245, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  33 training loss  tensor(0.1229)
# current learning rate  0.004851495
# betas tensor([0.2875, 0.1558, 0.6003, 0.8111, 0.4389], device='cuda:0')
# For agent  0  no of beta matches with peak 70
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 62
# For agent  3  no of beta matches with peak 46
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(0.0005), tensor(0.0003), tensor(0.0006), tensor(0.0003), tensor(0.0003)]
# max regret amoung agents tensor(0.0006)
# social cost  tensor(0.1219, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  34 minibatch loss   tensor(0.1220, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.2647, 0.7221, 0.5617, 0.2860, 0.0210], device='cuda:0')
# For agent  0  no of beta matches with peak 37
# For agent  1  no of beta matches with peak 55
# For agent  2  no of beta matches with peak 52
# For agent  3  no of beta matches with peak 38
# For agent  4  no of beta matches with peak 41
# regret is  [tensor(0.0007), tensor(0.0009), tensor(0.0010), tensor(0.0005), tensor(0.0006)]
# max regret amoung agents tensor(0.0010)
# social cost  tensor(0.1229, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  34 minibatch loss   tensor(0.1230, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.3479, 0.9423, 0.9961, 0.8962, 0.8657], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 49
# For agent  2  no of beta matches with peak 60
# For agent  3  no of beta matches with peak 52
# For agent  4  no of beta matches with peak 52
# regret is  [tensor(0.0003), tensor(0.0003), tensor(0.0004), tensor(0.0003), tensor(0.0004)]
# max regret amoung agents tensor(0.0004)
# social cost  tensor(0.1231, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  34 minibatch loss   tensor(0.1231, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  34 training loss  tensor(0.1227)
# current learning rate  0.004851495
# betas tensor([0.1955, 0.6598, 0.4267, 0.4415, 0.0885], device='cuda:0')
# For agent  0  no of beta matches with peak 58
# For agent  1  no of beta matches with peak 53
# For agent  2  no of beta matches with peak 44
# For agent  3  no of beta matches with peak 56
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(0.0005), tensor(0.0004), tensor(0.0006), tensor(0.0005), tensor(0.0005)]
# max regret amoung agents tensor(0.0006)
# social cost  tensor(0.1233, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  35 minibatch loss   tensor(0.1234, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.0177, 0.8004, 0.8399, 0.1107, 0.1278], device='cuda:0')
# For agent  0  no of beta matches with peak 63
# For agent  1  no of beta matches with peak 47
# For agent  2  no of beta matches with peak 66
# For agent  3  no of beta matches with peak 55
# For agent  4  no of beta matches with peak 60
# regret is  [tensor(1.8310e-06), tensor(3.5281e-05), tensor(8.8102e-05), tensor(5.2169e-05), tensor(2.7896e-06)]
# max regret amoung agents tensor(8.8102e-05)
# social cost  tensor(0.1214, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  35 minibatch loss   tensor(0.1214, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.4972, 0.1615, 0.9833, 0.8785, 0.7047], device='cuda:0')
# For agent  0  no of beta matches with peak 30
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 42
# For agent  3  no of beta matches with peak 53
# For agent  4  no of beta matches with peak 60
# regret is  [tensor(0.0001), tensor(0.0007), tensor(0.0006), tensor(0.0008), tensor(0.0009)]
# max regret amoung agents tensor(0.0009)
# social cost  tensor(0.1229, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  35 minibatch loss   tensor(0.1229, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  35 training loss  tensor(0.1226)
#  current lambda tensor(0.1000)  to minus  tensor(4.2737e-07)
#  _lamdda value  tensor(0.1000)
# current learning rate  0.004851495
# betas tensor([0.5609, 0.3561, 0.6538, 0.3038, 0.1270], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 58
# For agent  2  no of beta matches with peak 46
# For agent  3  no of beta matches with peak 55
# For agent  4  no of beta matches with peak 50
# regret is  [tensor(0.0007), tensor(0.0009), tensor(0.0011), tensor(0.0010), tensor(0.0009)]
# max regret amoung agents tensor(0.0011)
# social cost  tensor(0.1239, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  36 minibatch loss   tensor(0.1240, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.3050, 0.0452, 0.6149, 0.4697, 0.3814], device='cuda:0')
# For agent  0  no of beta matches with peak 67
# For agent  1  no of beta matches with peak 58
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 45
# For agent  4  no of beta matches with peak 45
# regret is  [tensor(0.0011), tensor(0.0006), tensor(0.0005), tensor(0.0007), tensor(0.0006)]
# max regret amoung agents tensor(0.0011)
# social cost  tensor(0.1226, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  36 minibatch loss   tensor(0.1227, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.0071, 0.9243, 0.5658, 0.0731, 0.9907], device='cuda:0')
# For agent  0  no of beta matches with peak 49
# For agent  1  no of beta matches with peak 41
# For agent  2  no of beta matches with peak 49
# For agent  3  no of beta matches with peak 50
# For agent  4  no of beta matches with peak 49
# regret is  [tensor(0.0005), tensor(0.0005), tensor(0.0006), tensor(0.0006), tensor(0.0005)]
# max regret amoung agents tensor(0.0006)
# social cost  tensor(0.1203, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  36 minibatch loss   tensor(0.1204, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  36 training loss  tensor(0.1224)
# current learning rate  0.004851495
# betas tensor([0.3342, 0.1423, 0.6439, 0.9574, 0.4276], device='cuda:0')
# For agent  0  no of beta matches with peak 55
# For agent  1  no of beta matches with peak 52
# For agent  2  no of beta matches with peak 49
# For agent  3  no of beta matches with peak 48
# For agent  4  no of beta matches with peak 36
# regret is  [tensor(0.0006), tensor(0.0003), tensor(0.0005), tensor(0.0005), tensor(0.0002)]
# max regret amoung agents tensor(0.0006)
# social cost  tensor(0.1245, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  37 minibatch loss   tensor(0.1246, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.9182, 0.9033, 0.6742, 0.6088, 0.3024], device='cuda:0')
# For agent  0  no of beta matches with peak 56
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 62
# For agent  4  no of beta matches with peak 46
# regret is  [tensor(0.0008), tensor(0.0008), tensor(0.0008), tensor(0.0010), tensor(0.0009)]
# max regret amoung agents tensor(0.0010)
# social cost  tensor(0.1212, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  37 minibatch loss   tensor(0.1212, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.0858, 0.3638, 0.0718, 0.1907, 0.9490], device='cuda:0')
# For agent  0  no of beta matches with peak 48
# For agent  1  no of beta matches with peak 51
# For agent  2  no of beta matches with peak 48
# For agent  3  no of beta matches with peak 54
# For agent  4  no of beta matches with peak 48
# regret is  [tensor(-0.0002), tensor(-0.0005), tensor(-0.0005), tensor(-0.0001), tensor(-0.0003)]
# max regret amoung agents tensor(-0.0001)
# social cost  tensor(0.1208, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  37 minibatch loss   tensor(0.1208, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  37 training loss  tensor(0.1222)
# current learning rate  0.004851495
# betas tensor([0.8444, 0.6882, 0.1944, 0.7621, 0.6200], device='cuda:0')
# For agent  0  no of beta matches with peak 46
# For agent  1  no of beta matches with peak 47
# For agent  2  no of beta matches with peak 52
# For agent  3  no of beta matches with peak 49
# For agent  4  no of beta matches with peak 38
# regret is  [tensor(0.0005), tensor(0.0011), tensor(0.0009), tensor(0.0008), tensor(0.0007)]
# max regret amoung agents tensor(0.0011)
# social cost  tensor(0.1234, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  38 minibatch loss   tensor(0.1235, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.7837, 0.8113, 0.7419, 0.9026, 0.9355], device='cuda:0')
# For agent  0  no of beta matches with peak 38
# For agent  1  no of beta matches with peak 54
# For agent  2  no of beta matches with peak 55
# For agent  3  no of beta matches with peak 50
# For agent  4  no of beta matches with peak 64
# regret is  [tensor(0.0002), tensor(0.0002), tensor(0.0002), tensor(0.0001), tensor(0.0003)]
# max regret amoung agents tensor(0.0003)
# social cost  tensor(0.1223, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  38 minibatch loss   tensor(0.1224, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.5588, 0.5472, 0.8769, 0.3962, 0.9224], device='cuda:0')
# For agent  0  no of beta matches with peak 36
# For agent  1  no of beta matches with peak 44
# For agent  2  no of beta matches with peak 42
# For agent  3  no of beta matches with peak 40
# For agent  4  no of beta matches with peak 37
# regret is  [tensor(0.0003), tensor(0.0003), tensor(0.0004), tensor(0.0004), tensor(0.0003)]
# max regret amoung agents tensor(0.0004)
# social cost  tensor(0.1200, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  38 minibatch loss   tensor(0.1200, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  38 training loss  tensor(0.1220)
# current learning rate  0.004851495
# betas tensor([0.5591, 0.4921, 0.9058, 0.2641, 0.7232], device='cuda:0')
# For agent  0  no of beta matches with peak 32
# For agent  1  no of beta matches with peak 63
# For agent  2  no of beta matches with peak 61
# For agent  3  no of beta matches with peak 50
# For agent  4  no of beta matches with peak 48
# regret is  [tensor(0.0005), tensor(0.0009), tensor(0.0009), tensor(0.0006), tensor(0.0006)]
# max regret amoung agents tensor(0.0009)
# social cost  tensor(0.1205, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  39 minibatch loss   tensor(0.1206, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.7145, 0.4225, 0.7873, 0.1345, 0.7884], device='cuda:0')
# For agent  0  no of beta matches with peak 28
# For agent  1  no of beta matches with peak 35
# For agent  2  no of beta matches with peak 42
# For agent  3  no of beta matches with peak 43
# For agent  4  no of beta matches with peak 40
# regret is  [tensor(0.0005), tensor(0.0004), tensor(0.0009), tensor(0.0006), tensor(0.0008)]
# max regret amoung agents tensor(0.0009)
# social cost  tensor(0.1233, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  39 minibatch loss   tensor(0.1234, device='cuda:0', grad_fn=<AddBackward0>)
# current learning rate  0.004851495
# betas tensor([0.9511, 0.4085, 0.2768, 0.0471, 0.1076], device='cuda:0')
# For agent  0  no of beta matches with peak 48
# For agent  1  no of beta matches with peak 47
# For agent  2  no of beta matches with peak 46
# For agent  3  no of beta matches with peak 60
# For agent  4  no of beta matches with peak 61
# regret is  [tensor(0.0002), tensor(-0.0001), tensor(-0.0003), tensor(7.3805e-05), tensor(-0.0003)]
# max regret amoung agents tensor(0.0002)
# social cost  tensor(0.1214, device='cuda:0', grad_fn=<MeanBackward0>)
# Epoch :  39 minibatch loss   tensor(0.1214, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  39 training loss  tensor(0.1218)
# betas tensor([0.6484, 0.0437, 0.8001, 0.4323, 0.1223], device='cuda:0')
# For agent  0  no of beta matches with peak 161
# For agent  1  no of beta matches with peak 146
# For agent  2  no of beta matches with peak 177
# For agent  3  no of beta matches with peak 141
# For agent  4  no of beta matches with peak 133
# regret is  [tensor(0.0006), tensor(0.0006), tensor(0.0007), tensor(0.0007), tensor(0.0006)]
# max regret amoung agents tensor(0.0007)
# social cost  tensor(0.1203, device='cuda:0', grad_fn=<MeanBackward0>)
# Testing Loss is  tensor(0.1204, device='cuda:0', grad_fn=<AddBackward0>)
# max regret is  tensor(0.0007)
